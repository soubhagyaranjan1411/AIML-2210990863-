# %% [markdown]
# # dataset amazon epurchases

# %%
https://www.kaggle.com/datasets/utkarsharya/ecommerce-purchases
# Out:
#   Cell In[1], line 1
#     https://www.kaggle.com/datasets/utkarsharya/ecommerce-purchases
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

data=pd.read_csv("Ecommerce Purchases")
data
# Out:
#                                                 Address    Lot AM or PM  \
# 0     16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1     9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                      Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3                 7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4     23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# ...                                                 ...    ...      ...
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# # Display Top 10 rows

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
top_10_rows = df.head(10)
top_10_rows
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
# 5  7502 Powell Mission Apt. 768\nTravisland, VA 3...  21 XT       PM
# 6     93971 Conway Causeway\nAndersonburgh, AZ 75107  96 Xt       AM
# 7  260 Rachel Plains Suite 366\nCastroberg, WV 24...  96 pG       PM
# 8            2129 Dylan Burg\nNew Michelle, ME 28650  45 JN       PM
# 9    3795 Dawson Extensions\nLake Tinafort, ID 88739  15 Ug       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# ...

# %% [markdown]
# # Display Last 10 rows

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
last_10_rows = df.tail(10)
last_10_rows
# Out:
#                                                 Address    Lot AM or PM  \
# 9990  75731 Molly Springs\nWest Danielle, VT 96934-5102  93 ty       PM
# 9991              PSC 8165, Box 8498\nAPO AP 60327-0346  50 dA       AM
# 9992  885 Allen Mountains Apt. 230\nWallhaven, LA 16995  40 vH       PM
# 9993  7555 Larson Locks Suite 229\nEllisburgh, MA 34...  72 jg       PM
# 9994       6276 Rojas Hollow\nLake Louis, WY 56410-7837  93 Ex       PM
# 9995      966 Castaneda Locks\nWest Juliafurt, CO 96415  92 XI       PM
# 9996  832 Curtis Dam Suite 785\nNorth Edwardburgh, T...  41 JY       AM
# 9997              Unit 4434 Box 6343\nDPO AE 28026-0283  74 Zh       AM
# 9998               0096 English Rest\nRoystad, IA 12457  74 cL       PM
# 9999     40674 Barrett Stravenue\nGrimesville, WI 79682  64 Hr       AM
#
#                                            Browser Info  \
# 9990  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_7_4;...
# 9991  Mozilla/5.0 (compatible; MSIE 8.0; Windows NT ...
# ...

# %% [markdown]
# # Check datatype  of Each coloum

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
data_types = df.dtypes
data_types
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %% [markdown]
# # check null values in the DataSet

# %%
null_values = df.isnull().sum()
null_values
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# # how many rows and coloumns in our dataset

# %%
num_rows, num_columns = df.shape
print(f'The dataset has {num_rows} rows and {num_columns} columns.')
# Out:
# The dataset has 10000 rows and 14 columns.

# %% [markdown]
# # Highest and lowest purchase price in dataset

# %%
highest_price = df['Purchase Price'].max()
lowest_price = df['Purchase Price'].min()
print(f'Highest Purchase Price: ${highest_price:.2f}')
print(f'Lowest Purchase Price: ${lowest_price:.2f}')
# Out:
# Highest Purchase Price: $99.99
# Lowest Purchase Price: $0.00

# %% [markdown]
# # Average purchase price

# %%
average_price = df['Purchase Price'].mean()
print(f'Average Purchase Price: ${average_price:.2f}')
# Out:
# Average Purchase Price: $50.35

# %% [markdown]
# #         # how many people have French 'fr' as their Language

# %%
#Import the data
import pandas as pd
import matplotlib as plt
import seaborn as sns
data=pd.read_csv("Ecommerce_Purchases")
#Count french speakers
french_speakers = data['Language'].value_counts().get('fr', 0)
print(f'Number of people with French as their language: {french_speakers}')
# Plot the bar graph
sns.countplot(x='Language', data=data)
plt.pyplot.title('Number of People Speaking Each Language')
plt.pyplot.xlabel('Language')
plt.pyplot.ylabel('Number of People')
plt.pyplot.show()
# Out:
# Number of people with French as their language: 1097

# %% [markdown]
# # job title contains engineer

# %%
#engineer_count = df[df['Job'].str.contains('engineer', case=False, na=False)].shape[0]
#print(f'The number of people with "engineer" in their job title: {engineer_count}')
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have already read the CSV file into a DataFrame
data_ecommerce = pd.read_csv("Ecommerce Purchases")

# Count the occurrences of each job title
job_title_counts = data_ecommerce['Job'].value_counts()

# Plot a bar graph
plt.figure(figsize=(14, 6))
sns.countplot(x='Job', data=data_ecommerce[data_ecommerce['Job'].str.contains('Engineer', case=False)], palette='viridis')
plt.title('Distribution of Job containing "Engineer" in Ecommerce Purchases')
plt.xlabel('Job')
plt.ylabel('Number of People')
plt.xticks(rotation=45, ha='right')
plt.show()

# Display the count of people with 'Engineer' in their job title
engineer_count = job_title_counts.get('Engineer', 0)
print(f'The number of people with "Engineer" in their job: {engineer_count}')
# Out:
# The number of people with "Engineer" in their job: 0

# %% [markdown]
# # find email of the person with the following IP address: 132.207.160.22

# %%
ip_address_to_search = '132.207.160.22'
email_of_person = df.loc[df['IP Address'] == ip_address_to_search, 'Email'].iloc[0]
print(f'The email of the person with IP address {ip_address_to_search}: {email_of_person}')
# Out:
# The email of the person with IP address 132.207.160.22: amymiller@morales-harrison.com

# %% [markdown]
# # how many people have Mastercard as their Credit Card Provider and Made A purchase above 50?

# %%
mastercard_above_50_count = df[(df['Credit Card'] == 'Mastercard') & (df['Purchase Price'] > 50)].shape[0]
print(f'The number of people with Mastercard as their credit card provider and made a purchase above $50: {mastercard_above_50_count}')
# Out:
# The number of people with Mastercard as their credit card provider and made a purchase above $50: 0

# %% [markdown]
# # Find Email of the person with the following Credit Card number:4105595335494659

# %%
import pandas as pd
df = pd.read_csv('Ecommerce Purchases')
credit_card_number_to_search = '4105595335494659'
if any(df['Credit Card'] == credit_card_number_to_search):
    email_of_person = df.loc[df['Credit Card'] == credit_card_number_to_search, 'Email'].iloc[0]
    print(f'The email of the person with Credit Card Number {credit_card_number_to_search}: {email_of_person}')
else:
    print(f'No record found for Credit Card Number {credit_card_number_to_search}')
# Out:
# No record found for Credit Card Number 4105595335494659

# %% [markdown]
# # how Many people Purchase During The Am and How Many People Purchase During Pm?

# %%
am_purchase_count = df[df['AM or PM'].str.contains('AM')].shape[0]
pm_purchase_count = df[df['AM or PM'].str.contains('PM')].shape[0]
print(f'Number of people who made purchases during AM: {am_purchase_count}')
print(f'Number of people who made purchases during PM: {pm_purchase_count}')
# Out:
# Number of people who made purchases during AM: 4932
# Number of people who made purchases during PM: 5068

# %% [markdown]
# # How Many People Have A credit Card That Expries In 2020

# %%
exp_2020_count = df[df['CC Exp Date'].str.contains('/20')].shape[0]
print(f'The number of people with a credit card expiring in 2020: {exp_2020_count}')
# Out:
# The number of people with a credit card expiring in 2020: 988

# %% [markdown]
# # Top 5 Most Popular EMail providers(eg Gmail.com, Yahoo.com,etc.)

# %%
df['Email Domain'] = df['Email'].str.split('@').str[1]
top_email_providers = df['Email Domain'].value_counts().head(5)
print('Top 5 Most Popular Email Providers:')
print(top_email_providers)
# Out:
# Top 5 Most Popular Email Providers:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: Email Domain, dtype: int64
